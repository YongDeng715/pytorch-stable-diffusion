# %%
import model_loader
import pipeline

import torch
from PIL import Image 
from transformers import CLIPTokenizer

DEVICE = "cpu" 
ALLOW_CUDA = True
ALLOW_MPS = False
 
if torch.cuda.is_available() and ALLOW_CUDA:
    DEVICE = "cuda"
elif (torch.backends.mps.is_built() or torch.backends.mps.is_available()) and ALLOW_MPS:
    DEVICE = "mps"
print(f"Using device: {DEVICE}")

tokenizer = CLIPTokenizer("../data/sd/tokenizer_vocab.json", merges_file="../data/sd/tokenizer_merges.txt")
model_file = "../data/sd/v1-5-pruned-emaonly.ckpt"
models = model_loader.preload_models_from_standard_weight(model_file, DEVICE)
# Out:
# Using device: cuda

# %%
## TEXT TO IMAGE ## 

# prompt = "A dog with sunglasses, wearing comfy hat, looking at camera, highly detailed, ultra sharp, cinematic, 100mm lens, 8k resolution."
prompt = "A cat stretching on the floor, highly detailed, ultra sharp, cinematic, 100mm lens, 8k resolution."
uncond_prompt = ""  # Also known as negative prompt
do_cfg = True
cfg_scale = 8  # min: 1, max: 14

strength = 0.9

## SAMPLER

sampler = "ddpm"
num_inference_steps = 5000
seed = 42

output_image = pipeline.generate(
    prompt=prompt,
    uncond_prompt=uncond_prompt,
    input_image=None,
    strength=strength,
    do_cfg=do_cfg,
    cfg_scale=cfg_scale,
    sampler_name=sampler,
    n_inference_steps=num_inference_steps,
    seed=seed,
    models=models,
    device=DEVICE,
    idle_device="cpu",
    tokenizer=tokenizer,
)

# Combine the input image and the output image into a single image.
Image.fromarray(output_image)
# Out:
# 100%|██████████| 5000/5000 [11:30<00:00,  7.25it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
## IMAGE TO IMAGE ## 

input_image = None
# Comment to disable image to image
image_path = "../images/cat.jpg"
input_image = Image.open(image_path)

"""
Higher values means more noise will be added to the input image, so the result 
will further from the input image. Lower values means less noise is added to 
the input image, so output will be closer to the input image.
"""
prompt = "A cat stretching on the floor, highly detailed, ultra sharp, cinematic, 100mm lens, 8k resolution."
uncond_prompt = ""  # Also known as negative prompt
do_cfg = True
cfg_scale = 8  # min: 1, max: 14

strength = 0.9

## SAMPLER
sampler = "ddpm"
num_inference_steps = 500
seed = 42

output_image = pipeline.generate(
    prompt=prompt,
    uncond_prompt=uncond_prompt,
    input_image=input_image,
    strength=strength,
    do_cfg=do_cfg,
    cfg_scale=cfg_scale,
    sampler_name=sampler,
    n_inference_steps=num_inference_steps,
    seed=seed,
    models=models,
    device=DEVICE,
    idle_device="cpu",
    tokenizer=tokenizer,
)

# Combine the input image and the output image into a single image.
Image.fromarray(output_image)
# Out:
# 100%|██████████| 450/450 [01:01<00:00,  7.34it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
img = Image.fromarray(output_image)
img.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 2
#       1 img = Image.fromarray(output_image)
# ----> 2 img.show()
#
# File d:\Code\anaconda\anaconda3\envs\vlm\Lib\site-packages\PIL\Image.py:2494, in Image.show(self, title)
#    2474 def show(self, title=None):
#    2475     """
#    2476     Displays this image. This method is mainly intended for debugging purposes.
#    2477
#    (...)   2491     :param title: Optional title to use for the image window, where possible.
#    2492     """
# -> 2494     _show(self, title=title)
#
# File d:\Code\anaconda\anaconda3\envs\vlm\Lib\site-packages\PIL\Image.py:3539, in _show(image, **options)
#    3536 def _show(image, **options):
#    3537     from . import ImageShow
# -> 3539     ImageShow.show(image, **options)
#
# File d:\Code\anaconda\anaconda3\envs\vlm\Lib\site-packages\PIL\ImageShow.py:62, in show(image, title, **options)
#      53 r"""
#      54 Display a given image.
#      55
#    (...)     59 :returns: ``True`` if a suitable viewer was found, ``False`` otherwise.
#      60 """
#      61 for viewer in _viewers:
# ---> 62     if viewer.show(image, title=title, **options):
#      63         return True
#      64 return False
#
# File d:\Code\anaconda\anaconda3\envs\vlm\Lib\site-packages\PIL\ImageShow.py:86, in Viewer.show(self, image, **options)
#      83     if image.mode != base:
#      84         image = image.convert(base)
# ---> 86 return self.show_image(image, **options)
#
# File d:\Code\anaconda\anaconda3\envs\vlm\Lib\site-packages\PIL\ImageShow.py:113, in Viewer.show_image(self, image, **options)
#     111 def show_image(self, image, **options):
#     112     """Display the given image."""
# --> 113     return self.show_file(self.save_image(image), **options)
#
# File d:\Code\anaconda\anaconda3\envs\vlm\Lib\site-packages\PIL\ImageShow.py:119, in Viewer.show_file(self, path, **options)
#     115 def show_file(self, path, **options):
#     116     """
#     117     Display given file.
#     118     """
# --> 119     os.system(self.get_command(path, **options))  # nosec
#     120     return 1
#
# KeyboardInterrupt:
